# %%
import sqlalchemy 
from sqlalchemy import create_engine
import psycopg2 
from dotenv import load_dotenv
import os
import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %%
from sqlalchemy import create_engine
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()

DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_NAME = os.getenv("DB_NAME")

engine = create_engine(f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@127.0.0.1:5432/{DB_NAME}")

try:
    df = pd.read_sql("SELECT source_city, COUNT(*) FROM properties GROUP BY source_city;", engine)
    print(df)
except Exception as e:
    print(f"Error: {e}")
# Out:
#    source_city  count
# 0      Houston     50
# 1       Austin     50
# 2  San_Antonio     50

# %%
df = pd.read_csv("data/transformed/all_properties_cleaned.csv")
df
# Out:
#                                       property_id  \
# 0            5509-Roanwood,-San-Antonio,-TX-78244
# 1            5528-Lochmoor,-San-Antonio,-TX-78244
# 2     5523-Lochmoor,-Apt-2,-San-Antonio,-TX-78244
# 3            5721-Lochmoor,-San-Antonio,-TX-78244
# 4     5519-Lochmoor,-Apt-2,-San-Antonio,-TX-78244
# ..                                            ...
# 145            3833-Cummins-St,-Houston,-TX-77027
# 146          10070-Westpark-Dr,-Houston,-TX-77042
# 147      14504-Briar-Forest-Dr,-Houston,-TX-77077
# 148      13155-Woodforest-Blvd,-Houston,-TX-77015
# 149  16755-W-Lake-Houston-Pkwy,-Houston,-TX-77044
#
#                                 formatted_address         city state  \
# 0            5509 Roanwood, San Antonio, TX 78244  San Antonio    TX
# 1            5528 Lochmoor, San Antonio, TX 78244  San Antonio    TX
# 2     5523 Lochmoor, Apt 2, San Antonio, TX 78244  San Antonio    TX
# 3            5721 Lochmoor, San Antonio, TX 78244  San Antonio    TX
# 4     5519 Lochmoor, Apt 2, San Antonio, TX 78244  San Antonio    TX
# ..                                            ...          ...   ...
# 145            3833 Cummins St, Houston, TX 77027      Houston    TX
# 146          10070 Westpark Dr, Houston, TX 77042      Houston    TX
# 147      14504 Briar Forest Dr, Houston, TX 77077      Houston    TX
# 148      13155 Woodforest Blvd, Houston, TX 77015      Houston    TX
# 149  16755 W Lake Houston Pkwy, Houston, TX 77044      Houston    TX
#
#      zip_code   latitude  longitude  property_type  bedrooms  bathrooms  \
# 0       78244  29.477359 -98.349687   Multi-Family       4.0        2.0
# 1       78244  29.477808 -98.350542  Single Family       2.0        1.5
# 2       78244  29.477526 -98.350809   Multi-Family       2.0        1.0
# 3       78244  29.476801 -98.350547      Apartment       2.0        2.0
# 4       78244  29.477460 -98.350786   Multi-Family       2.0        1.0
# ..        ...        ...        ...            ...       ...        ...
# 145     77027  29.730330 -95.436940      Apartment       0.0        1.0
# 146     77042  29.723450 -95.543340      Apartment       1.0        1.0
# 147     77077  29.757080 -95.639280      Apartment       1.0        1.0
# 148     77015  29.793900 -95.191820      Apartment       NaN        NaN
# 149     77044  29.964780 -95.170790      Apartment       1.0        1.0
#
#      square_footage  lot_size  year_built  tax_assessment_2024  \
# 0            1973.0       NaN      1985.0                  NaN
# 1             912.0       NaN         NaN                  NaN
# 2             800.0    8756.0      1984.0                  NaN
# 3               NaN       NaN         NaN                  NaN
# 4             800.0    8712.0      1984.0                  NaN
# ..              ...       ...         ...                  ...
# 145           685.0       NaN      2007.0                  NaN
# 146           623.0       NaN      1977.0                  NaN
# 147           817.0       NaN      1999.0                  NaN
# 148             NaN       NaN      1982.0                  NaN
# 149           759.0   46609.0      2016.0                  NaN
#
#      property_tax_2024 owner_name owner_occupied has_garage has_pool  \
# 0                  NaN        NaN            NaN        NaN      NaN
# 1                  NaN        NaN            NaN        NaN      NaN
# 2                  NaN        NaN            NaN        NaN      NaN
# 3                  NaN        NaN            NaN        NaN      NaN
# 4                  NaN        NaN            NaN        NaN      NaN
# ..                 ...        ...            ...        ...      ...
# 145                NaN        NaN            NaN        NaN      NaN
# 146                NaN        NaN            NaN        NaN      NaN
# 147                NaN        NaN            NaN        NaN      NaN
# 148                NaN        NaN            NaN        NaN      NaN
# 149                NaN        NaN            NaN        NaN      NaN
#
#      source_city
# 0    San_Antonio
# 1    San_Antonio
# 2    San_Antonio
# 3    San_Antonio
# 4    San_Antonio
# ..           ...
# 145      Houston
# 146      Houston
# 147      Houston
# 148      Houston
# 149      Houston
#
# [150 rows x 20 columns]

# %%
df.to_sql('properties', engine, if_exists='replace', index=False)
print("✓ Data loaded successfully!")
# Out:
# ✓ Data loaded successfully!
