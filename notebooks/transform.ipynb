# %%
import json
import pandas as pd
import os

# %%
# Define your cities
cities = ["San_Antonio", "Austin", "Houston"]
state = "TX"

# Load all properties
all_properties = []

for city in cities:
    file_path = f"data/raw/property_data_{city}_{state}.json"
    
    print(f"Loading {city}...")
    with open(file_path, "r") as f:
        data = json.load(f)
    
    # Add city identifier to each property
    for prop in data:
        prop['source_city'] = city
        prop['source_state'] = state
        all_properties.append(prop)
    
    print(f"✓ Loaded {len(data)} properties from {city}")

# Create DataFrame
df = pd.DataFrame(all_properties)

print(f"\n{'='*50}")
print(f"Total properties loaded: {len(df)}")
print(f"Total columns: {len(df.columns)}")
print(f"\nDataFrame shape: {df.shape}")
print(f"\nFirst few rows:")
print(df.head())

# View column names
print(f"\nAvailable columns:")
print(df.columns.tolist())
# Out:
# Loading San_Antonio...
# ✓ Loaded 50 properties from San_Antonio
# Loading Austin...
# ✓ Loaded 50 properties from Austin
# Loading Houston...
# ✓ Loaded 50 properties from Houston
#
# ==================================================
# Total properties loaded: 150
# Total columns: 28
#
# DataFrame shape: (150, 28)
#
# First few rows:
#                                             id  \
# 0         5509-Roanwood,-San-Antonio,-TX-78244
# 1         5528-Lochmoor,-San-Antonio,-TX-78244
# 2  5523-Lochmoor,-Apt-2,-San-Antonio,-TX-78244
# 3         5721-Lochmoor,-San-Antonio,-TX-78244
# 4  5519-Lochmoor,-Apt-2,-San-Antonio,-TX-78244
#
#                               formattedAddress   addressLine1 addressLine2  \
# 0         5509 Roanwood, San Antonio, TX 78244  5509 Roanwood         None
# 1         5528 Lochmoor, San Antonio, TX 78244  5528 Lochmoor         None
# 2  5523 Lochmoor, Apt 2, San Antonio, TX 78244  5523 Lochmoor        Apt 2
# 3         5721 Lochmoor, San Antonio, TX 78244  5721 Lochmoor         None
# 4  5519 Lochmoor, Apt 2, San Antonio, TX 78244  5519 Lochmoor        Apt 2
#
#           city state stateFips zipCode county countyFips  ...  source_state  \
# 0  San Antonio    TX        48   78244  Bexar        029  ...            TX
# 1  San Antonio    TX        48   78244  Bexar        029  ...            TX
# 2  San Antonio    TX        48   78244  Bexar        029  ...            TX
# 3  San Antonio    TX        48   78244  Bexar        029  ...            TX
# 4  San Antonio    TX        48   78244  Bexar        029  ...            TX
#
#    lotSize           features  assessorID  legalDescription  subdivision  \
# 0      NaN                NaN         NaN               NaN          NaN
# 1      NaN                NaN         NaN               NaN          NaN
# 2   8756.0  {'floorCount': 1}         NaN               NaN          NaN
# 3      NaN                NaN         NaN               NaN          NaN
# 4   8712.0                NaN         NaN               NaN          NaN
#
#    taxAssessments propertyTaxes owner  ownerOccupied
# 0             NaN           NaN   NaN            NaN
# 1             NaN           NaN   NaN            NaN
# 2             NaN           NaN   NaN            NaN
# 3             NaN           NaN   NaN            NaN
# 4             NaN           NaN   NaN            NaN
#
# [5 rows x 28 columns]
#
# Available columns:
# ['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city', 'state', 'stateFips', 'zipCode', 'county', 'countyFips', 'latitude', 'longitude', 'propertyType', 'bedrooms', 'bathrooms', 'squareFootage', 'yearBuilt', 'source_city', 'source_state', 'lotSize', 'features', 'assessorID', 'legalDescription', 'subdivision', 'taxAssessments', 'propertyTaxes', 'owner', 'ownerOccupied']

# %%
df = pd.json_normalize(all_properties)
print(df.head(2))
# Out:
#                                      id                      formattedAddress  \
# 0  5509-Roanwood,-San-Antonio,-TX-78244  5509 Roanwood, San Antonio, TX 78244
# 1  5528-Lochmoor,-San-Antonio,-TX-78244  5528 Lochmoor, San Antonio, TX 78244
#
#     addressLine1 addressLine2         city state stateFips zipCode county  \
# 0  5509 Roanwood         None  San Antonio    TX        48   78244  Bexar
# 1  5528 Lochmoor         None  San Antonio    TX        48   78244  Bexar
#
#   countyFips  ...  taxAssessments.2025.year  taxAssessments.2025.value  \
# 0        029  ...                       NaN                        NaN
# 1        029  ...                       NaN                        NaN
#
#   taxAssessments.2025.land  taxAssessments.2025.improvements  \
# 0                      NaN                               NaN
# 1                      NaN                               NaN
#
#    propertyTaxes.2013.year  propertyTaxes.2013.total  propertyTaxes.2014.year  \
# 0                      NaN                       NaN                      NaN
# 1                      NaN                       NaN                      NaN
#
#   propertyTaxes.2014.total propertyTaxes.2025.year  propertyTaxes.2025.total
# 0                      NaN                     NaN                       NaN
# 1                      NaN                     NaN                       NaN
#
# [2 rows x 128 columns]

# %%
for city in ["San_Antonio", "Austin", "Houston"]:
    city_df = df[df['source_city'] == city]
    print(f"\n{city} - Columns with non-null values:")
    print(city_df.columns[city_df.notna().any()].tolist())
# Out:
# San_Antonio - Columns with non-null values:
# ['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city', 'state', 'stateFips', 'zipCode', 'county', 'countyFips', 'latitude', 'longitude', 'propertyType', 'bedrooms', 'bathrooms', 'squareFootage', 'yearBuilt', 'source_city', 'source_state', 'lotSize', 'features.floorCount', 'assessorID', 'legalDescription', 'subdivision', 'ownerOccupied', 'features.architectureType', 'features.cooling', 'features.coolingType', 'features.exteriorType', 'features.fireplace', 'features.foundationType', 'features.garage', 'features.garageSpaces', 'features.garageType', 'features.heating', 'features.heatingType', 'features.roofType', 'features.roomCount', 'features.unitCount', 'taxAssessments.2015.year', 'taxAssessments.2015.value', 'taxAssessments.2015.land', 'taxAssessments.2015.improvements', 'taxAssessments.2016.year', 'taxAssessments.2016.value', 'taxAssessments.2016.land', 'taxAssessments.2016.improvements', 'taxAssessments.2017.year', 'taxAssessments.2017.value', 'taxAssessments.2017.land', 'taxAssessments.2017.improvements', 'taxAssessments.2018.year', 'taxAssessments.2018.value', 'taxAssessments.2018.land', 'taxAssessments.2018.improvements', 'taxAssessments.2019.year', 'taxAssessments.2019.value', 'taxAssessments.2019.land', 'taxAssessments.2019.improvements', 'taxAssessments.2020.year', 'taxAssessments.2020.value', 'taxAssessments.2020.land', 'taxAssessments.2020.improvements', 'taxAssessments.2021.year', 'taxAssessments.2021.value', 'taxAssessments.2021.land', 'taxAssessments.2021.improvements', 'taxAssessments.2022.year', 'taxAssessments.2022.value', 'taxAssessments.2022.land', 'taxAssessments.2022.improvements', 'taxAssessments.2023.year', 'taxAssessments.2023.value', 'taxAssessments.2023.land', 'taxAssessments.2023.improvements', 'taxAssessments.2024.year', 'taxAssessments.2024.value', 'taxAssessments.2024.land', 'taxAssessments.2024.improvements', 'propertyTaxes.2015.year', 'propertyTaxes.2015.total', 'propertyTaxes.2016.year', 'propertyTaxes.2016.total', 'propertyTaxes.2017.year', 'propertyTaxes.2017.total', 'propertyTaxes.2018.year', 'propertyTaxes.2018.total', 'propertyTaxes.2019.year', 'propertyTaxes.2019.total', 'propertyTaxes.2020.year', 'propertyTaxes.2020.total', 'propertyTaxes.2021.year', 'propertyTaxes.2021.total', 'propertyTaxes.2022.year', 'propertyTaxes.2022.total', 'propertyTaxes.2023.year', 'propertyTaxes.2023.total', 'propertyTaxes.2024.year', 'propertyTaxes.2024.total', 'owner.names', 'owner.type', 'owner.mailingAddress.id', 'owner.mailingAddress.formattedAddress', 'owner.mailingAddress.addressLine1', 'owner.mailingAddress.addressLine2', 'owner.mailingAddress.city', 'owner.mailingAddress.state', 'owner.mailingAddress.stateFips', 'owner.mailingAddress.zipCode', 'features.pool']
#
# Austin - Columns with non-null values:
# ['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city', 'state', 'stateFips', 'zipCode', 'county', 'countyFips', 'latitude', 'longitude', 'propertyType', 'bedrooms', 'bathrooms', 'squareFootage', 'yearBuilt', 'source_city', 'source_state', 'lotSize', 'features.floorCount', 'assessorID', 'legalDescription', 'subdivision', 'ownerOccupied', 'features.architectureType', 'features.fireplace', 'features.foundationType', 'features.roofType', 'features.unitCount', 'taxAssessments.2016.year', 'taxAssessments.2016.value', 'taxAssessments.2016.land', 'taxAssessments.2016.improvements', 'taxAssessments.2017.year', 'taxAssessments.2017.value', 'taxAssessments.2017.land', 'taxAssessments.2017.improvements', 'taxAssessments.2018.year', 'taxAssessments.2018.value', 'taxAssessments.2018.land', 'taxAssessments.2018.improvements', 'taxAssessments.2019.year', 'taxAssessments.2019.value', 'taxAssessments.2019.land', 'taxAssessments.2019.improvements', 'taxAssessments.2020.year', 'taxAssessments.2020.value', 'taxAssessments.2020.land', 'taxAssessments.2020.improvements', 'taxAssessments.2021.year', 'taxAssessments.2021.value', 'taxAssessments.2021.land', 'taxAssessments.2021.improvements', 'taxAssessments.2022.year', 'taxAssessments.2022.value', 'taxAssessments.2022.land', 'taxAssessments.2022.improvements', 'taxAssessments.2023.year', 'taxAssessments.2023.value', 'taxAssessments.2023.land', 'taxAssessments.2023.improvements', 'propertyTaxes.2016.year', 'propertyTaxes.2016.total', 'propertyTaxes.2017.year', 'propertyTaxes.2017.total', 'propertyTaxes.2018.year', 'propertyTaxes.2018.total', 'propertyTaxes.2019.year', 'propertyTaxes.2019.total', 'propertyTaxes.2020.year', 'propertyTaxes.2020.total', 'propertyTaxes.2021.year', 'propertyTaxes.2021.total', 'propertyTaxes.2022.year', 'propertyTaxes.2022.total', 'propertyTaxes.2023.year', 'propertyTaxes.2023.total', 'owner.names', 'owner.mailingAddress.id', 'owner.mailingAddress.addressLine1', 'owner.mailingAddress.addressLine2', 'owner.mailingAddress.city', 'owner.mailingAddress.state', 'owner.mailingAddress.stateFips', 'owner.mailingAddress.zipCode', 'taxAssessments.2013.year', 'taxAssessments.2013.value', 'taxAssessments.2013.land', 'taxAssessments.2013.improvements', 'taxAssessments.2014.year', 'taxAssessments.2014.value', 'taxAssessments.2014.land', 'taxAssessments.2014.improvements', 'taxAssessments.2025.year', 'taxAssessments.2025.value', 'taxAssessments.2025.land', 'taxAssessments.2025.improvements', 'propertyTaxes.2013.year', 'propertyTaxes.2013.total', 'propertyTaxes.2014.year', 'propertyTaxes.2014.total', 'propertyTaxes.2025.year', 'propertyTaxes.2025.total']
#
# Houston - Columns with non-null values:
# ['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city', 'state', 'stateFips', 'zipCode', 'county', 'countyFips', 'latitude', 'longitude', 'propertyType', 'bedrooms', 'bathrooms', 'squareFootage', 'yearBuilt', 'source_city', 'source_state', 'lotSize', 'features.floorCount', 'assessorID', 'legalDescription', 'subdivision', 'ownerOccupied', 'features.architectureType', 'features.cooling', 'features.coolingType', 'features.exteriorType', 'features.fireplace', 'features.foundationType', 'features.heating', 'features.heatingType', 'features.roomCount', 'features.unitCount', 'taxAssessments.2018.year', 'taxAssessments.2018.value', 'taxAssessments.2018.land', 'taxAssessments.2018.improvements', 'propertyTaxes.2018.year', 'propertyTaxes.2018.total', 'owner.names', 'owner.mailingAddress.id', 'owner.mailingAddress.addressLine1', 'owner.mailingAddress.city', 'owner.mailingAddress.state', 'owner.mailingAddress.stateFips', 'owner.mailingAddress.zipCode']

# %%
# Keep only essential columns
essential_columns = [
    'id', 'formattedAddress', 'city', 'state', 'zipCode', 
    'latitude', 'longitude', 'propertyType', 'bedrooms', 
    'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt',
    'taxAssessments.2024.value', 'propertyTaxes.2024.total',
    'owner.names', 'ownerOccupied', 'features.garage', 
    'features.pool', 'source_city'
]

# Filter to existing columns
existing_cols = [col for col in essential_columns if col in df.columns]
df_clean = df[existing_cols].copy()

# %%
# Rename columns to snake_case
df_clean = df_clean.rename(columns={
    'id': 'property_id',
    'formattedAddress': 'formatted_address',
    'city': 'city',
    'state': 'state',
    'zipCode': 'zip_code',
    'latitude': 'latitude',
    'longitude': 'longitude',
    'propertyType': 'property_type',
    'bedrooms': 'bedrooms',
    'bathrooms': 'bathrooms',
    'squareFootage': 'square_footage',
    'lotSize': 'lot_size',
    'yearBuilt': 'year_built',
    'taxAssessments.2024.value': 'tax_assessment_2024',
    'propertyTaxes.2024.total': 'property_tax_2024',
    'owner.names': 'owner_name',
    'ownerOccupied': 'owner_occupied',
    'features.garage': 'has_garage',
    'features.pool': 'has_pool',
    'source_city': 'source_city'
})

print("Column names cleaned!")
print(df_clean.columns.tolist())
# Out:
# Column names cleaned!
# ['property_id', 'formatted_address', 'city', 'state', 'zip_code', 'latitude', 'longitude', 'property_type', 'bedrooms', 'bathrooms', 'square_footage', 'lot_size', 'year_built', 'tax_assessment_2024', 'property_tax_2024', 'owner_name', 'owner_occupied', 'has_garage', 'has_pool', 'source_city']

# %%
df
# Out:
#                                                id  \
# 0            5509-Roanwood,-San-Antonio,-TX-78244
# 1            5528-Lochmoor,-San-Antonio,-TX-78244
# 2     5523-Lochmoor,-Apt-2,-San-Antonio,-TX-78244
# 3            5721-Lochmoor,-San-Antonio,-TX-78244
# 4     5519-Lochmoor,-Apt-2,-San-Antonio,-TX-78244
# ..                                            ...
# 145            3833-Cummins-St,-Houston,-TX-77027
# 146          10070-Westpark-Dr,-Houston,-TX-77042
# 147      14504-Briar-Forest-Dr,-Houston,-TX-77077
# 148      13155-Woodforest-Blvd,-Houston,-TX-77015
# 149  16755-W-Lake-Houston-Pkwy,-Houston,-TX-77044
#
#                                  formattedAddress               addressLine1  \
# 0            5509 Roanwood, San Antonio, TX 78244              5509 Roanwood
# 1            5528 Lochmoor, San Antonio, TX 78244              5528 Lochmoor
# 2     5523 Lochmoor, Apt 2, San Antonio, TX 78244              5523 Lochmoor
# 3            5721 Lochmoor, San Antonio, TX 78244              5721 Lochmoor
# 4     5519 Lochmoor, Apt 2, San Antonio, TX 78244              5519 Lochmoor
# ..                                            ...                        ...
# 145            3833 Cummins St, Houston, TX 77027            3833 Cummins St
# 146          10070 Westpark Dr, Houston, TX 77042          10070 Westpark Dr
# 147      14504 Briar Forest Dr, Houston, TX 77077      14504 Briar Forest Dr
# 148      13155 Woodforest Blvd, Houston, TX 77015      13155 Woodforest Blvd
# 149  16755 W Lake Houston Pkwy, Houston, TX 77044  16755 W Lake Houston Pkwy
#
#     addressLine2         city state stateFips zipCode  county countyFips  ...  \
# 0           None  San Antonio    TX        48   78244   Bexar        029  ...
# 1           None  San Antonio    TX        48   78244   Bexar        029  ...
# 2          Apt 2  San Antonio    TX        48   78244   Bexar        029  ...
# 3           None  San Antonio    TX        48   78244   Bexar        029  ...
# 4          Apt 2  San Antonio    TX        48   78244   Bexar        029  ...
# ..           ...          ...   ...       ...     ...     ...        ...  ...
# 145         None      Houston    TX        48   77027  Harris        201  ...
# 146         None      Houston    TX        48   77042  Harris        201  ...
# 147         None      Houston    TX        48   77077  Harris        201  ...
# 148         None      Houston    TX        48   77015  Harris        201  ...
# 149         None      Houston    TX        48   77044  Harris        201  ...
#
#      taxAssessments.2025.year  taxAssessments.2025.value  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 145                       NaN                        NaN
# 146                       NaN                        NaN
# 147                       NaN                        NaN
# 148                       NaN                        NaN
# 149                       NaN                        NaN
#
#     taxAssessments.2025.land  taxAssessments.2025.improvements  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
# ..                       ...                               ...
# 145                      NaN                               NaN
# 146                      NaN                               NaN
# 147                      NaN                               NaN
# 148                      NaN                               NaN
# 149                      NaN                               NaN
#
#      propertyTaxes.2013.year  propertyTaxes.2013.total  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ..                       ...                       ...
# 145                      NaN                       NaN
# 146                      NaN                       NaN
# 147                      NaN                       NaN
# 148                      NaN                       NaN
# 149                      NaN                       NaN
#
#      propertyTaxes.2014.year propertyTaxes.2014.total propertyTaxes.2025.year  \
# 0                        NaN                      NaN                     NaN
# 1                        NaN                      NaN                     NaN
# 2                        NaN                      NaN                     NaN
# 3                        NaN                      NaN                     NaN
# 4                        NaN                      NaN                     NaN
# ..                       ...                      ...                     ...
# 145                      NaN                      NaN                     NaN
# 146                      NaN                      NaN                     NaN
# 147                      NaN                      NaN                     NaN
# 148                      NaN                      NaN                     NaN
# 149                      NaN                      NaN                     NaN
#
#      propertyTaxes.2025.total
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 145                       NaN
# 146                       NaN
# 147                       NaN
# 148                       NaN
# 149                       NaN
#
# [150 rows x 128 columns]

# %%
# Create directory structure
os.makedirs("data/transformed", exist_ok=True)

# Save cleaned data
df_clean.to_csv("data/transformed/all_properties_cleaned.csv", index=False)
print("✓ Saved cleaned data")
# Out:
# ✓ Saved cleaned data
